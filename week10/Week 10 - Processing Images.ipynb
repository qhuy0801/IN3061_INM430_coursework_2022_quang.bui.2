# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Images: load, display and colours
#
# ...

# %%
# Images urls
blood_cells_url = "http://upload.wikimedia.org/wikipedia/commons/8/82/SEM_blood_cells.jpg"
claude_monet_url = "https://upload.wikimedia.org/wikipedia/commons/5/54/Claude_Monet%2C_Impression%2C_soleil_levant.jpg"

# Import the images
blood_cells = io.imread(blood_cells_url)
claude_monet = io.imread(claude_monet_url)

# %%
# Show the image
plt.imshow(blood_cells)

# %%
blood_cells_thresholded = blood_cells[:,:,0]>100

# %%
# Show the image
plt.imshow(blood_cells_thresholded)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 15))
ax1.imshow(blood_cells)
ax2.imshow(blood_cells_thresholded)

# %%
# Create filter matrix
edges_matrix = np.array([[0, -1, 0],
                         [-1, 4, -1],
                         [0, -1, 0]])

blood_cells_arr = np.array(blood_cells)/255.0

blood_cells_arr
# Out:
# array([[[0.55686275, 0.55686275, 0.55686275],
#         [0.5372549 , 0.5372549 , 0.5372549 ],
#         [0.53333333, 0.53333333, 0.53333333],
#         ...,
#         [0.67058824, 0.67058824, 0.67058824],
#         [0.67058824, 0.67058824, 0.67058824],
#         [0.68627451, 0.68627451, 0.68627451]],
#
#        [[0.54117647, 0.54117647, 0.54117647],
#         [0.5372549 , 0.5372549 , 0.5372549 ],
#         [0.53333333, 0.53333333, 0.53333333],
#         ...,
#         [0.6745098 , 0.6745098 , 0.6745098 ],
#         [0.6745098 , 0.6745098 , 0.6745098 ],
#         [0.67843137, 0.67843137, 0.67843137]],
#
#        [[0.53333333, 0.53333333, 0.53333333],
#         [0.52941176, 0.52941176, 0.52941176],
#         [0.53333333, 0.53333333, 0.53333333],
#         ...,
#         [0.66666667, 0.66666667, 0.66666667],
#         [0.67843137, 0.67843137, 0.67843137],
#         [0.6745098 , 0.6745098 , 0.6745098 ]],
#
#        ...,
#
#        [[0.76078431, 0.76078431, 0.76078431],
# ...
