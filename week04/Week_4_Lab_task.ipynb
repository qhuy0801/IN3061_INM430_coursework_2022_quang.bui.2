# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("censusCrimeClean.csv", header = 0)
df.head()
# Out:
#          communityname  fold  population  householdsize  racepctblack  \
# 0         Lakewoodcity     1        0.19           0.33          0.02
# 1          Tukwilacity     1        0.00           0.16          0.12
# 2         Aberdeentown     1        0.00           0.42          0.49
# 3  Willingborotownship     1        0.04           0.77          1.00
# 4    Bethlehemtownship     1        0.01           0.55          0.02
#
#    racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# 0          0.90          0.12         0.17         0.34         0.47  ...
# 1          0.74          0.45         0.07         0.26         0.59  ...
# 2          0.56          0.17         0.04         0.39         0.47  ...
# 3          0.08          0.12         0.10         0.51         0.50  ...
# 4          0.95          0.09         0.05         0.38         0.38  ...
#
#    NumStreet  PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# ...

# %%
medIncome = df["medIncome"]
ViolentCrimesPerPop = df["ViolentCrimesPerPop"]

# %%
pearCorr = stats.pearsonr(medIncome, ViolentCrimesPerPop)
spearmCorr = stats.spearmanr(medIncome, ViolentCrimesPerPop)

# %%
print(pearCorr)
print(spearmCorr)
# Out:
# (-0.4242206167261274, 6.334424808039891e-88)
# SpearmanrResult(correlation=-0.482169950997556, pvalue=1.2978853095169542e-116)

# %%
plt.scatter(medIncome, ViolentCrimesPerPop)

# %% [markdown]
# For the selected collumns, Person ans Spearman give 2 different value, however, the there won't be a large gap between two values (0.42 vs 0.48). However, p-values show a noticable different.

# %% [markdown]
# Now, we will draw scatter plot in a loop for all other columns

# %%
# TODO

# %%
df_2 = pd.read_csv("heart.csv", header = 0)
df_2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
def gender(row):
    if row["sex"] == 1:
        val = "male"
    else:
        val = "female"
    return val

# %%
def heartDisease(row):
    if row["target"] == 1:
        val = "yes"
    else:
        val = "no"
    return val

# %%
df_2['gender'] = df.apply(gender, axis=1)
df_2['hasHeartDisease'] = df.apply(heartDisease, axis=1)
df_2.head()

# %%
# TODO
