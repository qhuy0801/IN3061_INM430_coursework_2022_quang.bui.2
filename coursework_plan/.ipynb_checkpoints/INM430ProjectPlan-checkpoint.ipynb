# %% [markdown]
# # IN3061/INM430 - Tiny DS Project Progress Report
#
#
# ***
#
# Student Name: **Quang Huy Bui**
#
# Project Title: **ABC**
#
# ***

# %% [markdown]
# ## Application domain and datasets:
#
# Application domain:
# * Energy resource planning:
#     * Sustainably approach to energy distribution
# * Commodity trading strategies (energy products: oil, natural gas, etc.)
#     * Stabilise and reduce energy price
#     * Help with citizen welfare: living cost
#
#
# The data set: [World Energy Consumption](https://www.kaggle.com/datasets/pralabhpoudel/world-energy-consumption)
#
#
# ## Well-motivated analytical questions:
#
# -	How much percentage of our power comes from fossil fuels?
# -	How can fossil fuel price change affect our energy price?
# -	Which country has the advantage of producing traditional/ sustainable energy and selling it?
# -	What is the method to increase renewable energy share?
# -	How can we reduce the cost of energy?
#
# ## Plan (maximum 200 words):
#
# -	Aggregate the data and calculate the area that uses the most energy (sustainable/ fossil energy)
# -	Facet to collect the data about energy consumption, handle the missing values, outliers build a regression model about the energy usage trend to predict the need
# &rarr; Therefore, we can estimate the change in fossil fuels price/ availability effect on the energy bill of specific regions.
# -	Collect more datasets about region geographic specification to analyse the capability of making energy
# -	Collect more datasets about the power demand season-wise to suggest energy plans for cost reduction
#
#
# ## Specific questions to us
#
# -	How many datasets (maximum) should be used in this coursework?
# -	Is it better to focus on small-scale (daily life) issues or general issues which should be in government application?
# -	For the conclusion of this coursework, do we have to deliver a solution to a specific problem or just a general perspective/ opinion?
#
# ## Initial investigations

# %%
# libraries
import pandas as pd
import numpy as np

# import the dataset
df = pd.read_csv("World Energy Consumption.csv", header = 0)

# %%
df.describe()
# Out:
#                year  coal_prod_change_pct  coal_prod_change_twh  \
# count  17432.000000           7445.000000          10394.000000
# mean    1973.094367             20.830774              8.798102
# std       34.333995            697.178744            135.503698
# min     1900.000000           -100.000000          -2326.870000
# 25%     1946.000000             -1.532000              0.000000
# 50%     1983.000000              0.000000              0.000000
# 75%     2002.000000              7.690000              0.334000
# max     2020.000000          44965.754000           3060.593000
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# count         4.862000e+03          7893.000000          6521.000000
# mean          1.921623e+14            14.369018            18.242190
# std           1.339910e+16            85.415649           335.492675
# min          -1.000000e+02         -1054.320000          -100.000000
# ...

# %%
countries = df['country'].unique()
countries.size
# Out:
# 242

# %% [markdown]
# As we can see, the statistic dated from 1900 to 2020 - an extended period, is enough for us to analyse historical trends and new enough to predict the later values.
# It also recorded data from 242 countries, allowing us to perform the analytical task globally.
# However, many aspects of the energy usage story are still missing from the dataset (e.g., seasonal energy consumption, domestic consumption via electrical devices/ purpose, etc.). Therefore, more datasets should be collected for the task.
